# %%
import pandas as pd

# %%
df = pd.read_csv('./data/sample_data.csv')

# %%
df
# Out:
#      timestamp      service                                          comment  \
# 0   2025-08-20    cafeteria    The food was tasty but the queue was too long
# 1   2025-08-20    cafeteria                 Good portions and friendly staff
# 2   2025-08-20    cafeteria                 Prices are too high for students
# 3   2025-08-21       hostel                      My room was clean and quiet
# 4   2025-08-21       hostel                Bathrooms were dirty this morning
# 5   2025-08-21       hostel       The generator worked but it was very noisy
# 6   2025-08-22      library                The library is quiet and well lit
# 7   2025-08-22      library                  No seats were available at noon
# 8   2025-08-22      library  Wi-Fi keeps disconnecting during study sessions
# 9   2025-08-23    transport                The shuttle arrived on time today
# 10  2025-08-23    transport                               Bus was late again
# ...
